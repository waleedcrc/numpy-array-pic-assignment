# %% [markdown]
#  # import necessary  libraries

# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pylab as plt
import matplotlib.image

# %% [markdown]
# # load direct file data method
#
#  Set the directory you want to start from ,this code to direct load your data

# %%
# Set the directory you want to start from ,this code to direct load your data 
rootDir = 'photos'
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        print('\t%s' % fname)
# Out:
# Found directory: photos
# 	1.jpg
# 	1_7ehkFmbzBXwD2pPyDr-gnw.png
# 	2.jpg
# 	3.jpg
# 	4.jpg
# 	5.jpg
# 	base_01_pandas_5_0.png
# 	dataframe.png
# 	finallpandas.png
# 	series-and-dataframe.width-1200.png
# 	series1.png
# 	series2.png
# 	Untitled.png

# %% [markdown]
# # first create to list
#
# *put one picture in main_list then changed his original array into np

# %%
main_list =[]
im = Image.open(dirName+"\\"+fileList[0])#filelist[0] mean they only first image
print("----------X------------X-----------------------X\n\n")
im.show()
original_array = np.array(im)
# Out:
# ----------X------------X-----------------------X

# %% [markdown]
# #
# print original shape,size,array

# %%
print(original_array.shape)
print(original_array.size)
#print(original_array)
#print("\n\n----------X------------X-----------------------X\n\n")
# Out:
# (2160, 3840, 3)
# 24883200

# %% [markdown]
# # now change into resize (200,200) then append in resized_array

# %%
new_image =im.resize((200,200))
resized_array = np.array(new_image)
print (new_image)
main_list.append(resized_array)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x3C74948>

# %%
print (resized_array.size)
print (resized_array.shape)
#print (resized_array)
# Out:
# 120000
# (200, 200, 3)

# %%
#plt.imshow(im)
plt.imshow(resized_array)

# %%
#print (main_list)

# %% [markdown]
# # Now you can add all pic ,photos into main list and change his shape and array resized

# %%
pic = 2
for i in range (1,len(fileList)):
    print("PIC NO :",pic)
    im = Image.open(dirName+"\\"+fileList[i])
    #print("----------X------------X-----------------------X\n\n")
    im.show()
    original_array = np.array(im)
    print(original_array.shape)
    print(original_array.size)
    #print(original_array)
    print("\n\n----------X------------X-----------------------X\n\n")
    new_image = im.resize((200, 200)) 
    resized_array = np.array(new_image)
    print(resized_array.size)
    print(resized_array.shape)
    #print(resized_array)
    print("APPENDING TIME")
    main_list.append(resized_array)
    pic = pic+1
# Out:
# PIC NO : 2
# (352, 494, 3)
# 521664
#
#
# ----------X------------X-----------------------X
#
#
# 120000
# (200, 200, 3)
# APPENDING TIME
# PIC NO : 3
# (1200, 1600, 3)
# 5760000
#
#
# ----------X------------X-----------------------X
#
#
# 120000
# (200, 200, 3)
# APPENDING TIME
# PIC NO : 4
# (480, 640, 3)
# 921600
#
#
# ----------X------------X-----------------------X
#
#
# 120000
# (200, 200, 3)
# APPENDING TIME
# PIC NO : 5
# (2160, 3840, 3)
# 24883200
#
#
# ----------X------------X-----------------------X
#
#
# 120000
# (200, 200, 3)
# APPENDING TIME
# PIC NO : 6
# (2160, 3840, 3)
# 24883200
#
#
# ----------X------------X-----------------------X
#
#
# 120000
# (200, 200, 3)
# APPENDING TIME
# PIC NO : 7
# (454, 858, 4)
# 1558128
#
#
# ----------X------------X-----------------------X
#
#
# 160000
# (200, 200, 4)
# APPENDING TIME
# PIC NO : 8
# (408, 617, 3)
# 755208
#
#
# ----------X------------X-----------------------X
#
#
# 120000
# (200, 200, 3)
# APPENDING TIME
# PIC NO : 9
# ...

# %%
plt.imshow(new_image)
#plt.imshow(im)    
#plt.imshow(resized_array)
#plt.imshow(PIC NO : 12)

# %%
len(main_list)
# Out:
# 13

# %%
#main_list

# %%
main_list = np.array(main_arr)
print("FINAL NUMPY ARRAY :\n\n ",main_arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-1e2fa1da97fc> in <module>
# ----> 1 main_list = np.array(main_arr)
#       2 print("FINAL NUMPY ARRAY :\n\n ",main_arr)
#
# NameError: name 'main_arr' is not defined

# %%
main_arr.shape

# %%
main_arr.ndim

# %%
main_arr.size

# %%
len(main_list)
# Out:
# 13
